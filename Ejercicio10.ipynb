# %% [markdown]
# <a href="https://colab.research.google.com/github/arturomolin/Tarea1/blob/main/Ejercicio10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Nathalia Ballesteros
import math

def metodo_secante():
    # Solicitamos los datos de entrada
    funcion_str = input("Ingrese la función (en términos de x): ")
    x0 = float(input("Ingrese el primer punto inicial (x0): "))
    x1 = float(input("Ingrese el segundo punto inicial (x1): "))
    tolerancia = float(input("Ingrese la tolerancia: "))
    max_iter = int(input("Ingrese el número máximo de iteraciones: "))

    # Definimos la función a partir de la entrada del usuario
    def f(x):
        return eval(funcion_str, {'x': x, 'exp': math.exp, 'cos': math.cos, 'sin': math.sin, 'log': math.log, 'sqrt': math.sqrt})

    iteracion = 0
    while iteracion < max_iter:
        f_x0 = f(x0)
        f_x1 = f(x1)
        if abs(f_x1) < tolerancia:
            print(f"Raíz encontrada en x = {x1} después de {iteracion} iteraciones.")
            return x1
        if f_x1 - f_x0 == 0:
            print("División por cero. El método no puede continuar.")
            return None
        x_nuevo = x1 - f_x1 * (x1 - x0) / (f_x1 - f_x0)
        x0, x1 = x1, x_nuevo
        iteracion += 1

    print(f"Máximo número de iteraciones alcanzado. Última aproximación: x = {x1}")
    return x1

metodo_secante()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Ingrese la función (en términos de x): exp(x) - 3*x**2
Ingrese el primer punto inicial (x0): 0
Ingrese el segundo punto inicial (x1): 1
Ingrese la tolerancia: 1e-5
Ingrese el número máximo de iteraciones: 100

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Ingrese la función (en términos de x): exp(x) + 2**(-x) + 2*cos(x) - 6
Ingrese el primer punto inicial (x0): 1
Ingrese el segundo punto inicial (x1): 2
Ingrese la tolerancia: 1e-5
Ingrese el número máximo de iteraciones: 100

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Ingrese la función (en términos de x): 2*x*cos(2*x) - (x-2)**2
Ingrese el primer punto inicial (x0): 2
Ingrese el segundo punto inicial (x1): 3
Ingrese la tolerancia: 1e-5
Ingrese el número máximo de iteraciones: 100
